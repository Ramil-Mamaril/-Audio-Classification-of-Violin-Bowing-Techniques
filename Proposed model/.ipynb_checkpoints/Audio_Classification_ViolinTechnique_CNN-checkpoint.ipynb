# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os, json, math, librosa

import IPython.display as ipd
import librosa.display

import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D,  MaxPool2D, Flatten, Dense

import sklearn.model_selection as sk

from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATASET_PATH = '/content/drive/MyDrive/Final_Data/'
JSON_PATH = "data_10.json"
SAMPLE_RATE = 44100
TRACK_DURATION = 3 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=26, n_fft=4096, hop_length=1024, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file

                file_path = os.path.join(dirpath, f)
            
                if file_path != 'D:/AI/DataSet/Legato/Legato_024.wav':

                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                
                
                    # process all segments of audio file
                    for d in range(num_segments):

                        # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        # extract mfcc
                        mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)
# Out:
# Processing: Legato
# /content/drive/MyDrive/Final_Data/Legato/Legato_002.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_002.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_002.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_002.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_002.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_002.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_001.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_001.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_001.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_001.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_001.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_001.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_004.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_004.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_004.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_004.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_004.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_003.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_003.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_003.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_003.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_003.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_006.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_006.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_006.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_006.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_006.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_006.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_007.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_007.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_007.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_007.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_007.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_007.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_005.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_005.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_005.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_005.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_005.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_005.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_013.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_013.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_013.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_013.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_013.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_013.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_008.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_008.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_008.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_008.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_008.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_008.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_009.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_009.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_009.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_009.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_009.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_009.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_010.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_010.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_010.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_010.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_010.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_010.wav, segment:6
# /content/drive/MyDrive/Final_Data/Legato/Legato_015.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_015.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_015.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_015.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_015.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_012.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_012.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato_012.wav, segment:3
# /content/drive/MyDrive/Final_Data/Legato/Legato_012.wav, segment:4
# /content/drive/MyDrive/Final_Data/Legato/Legato_012.wav, segment:5
# /content/drive/MyDrive/Final_Data/Legato/Legato_014.wav, segment:1
# /content/drive/MyDrive/Final_Data/Legato/Legato_014.wav, segment:2
# /content/drive/MyDrive/Final_Data/Legato/Legato
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_018.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_018.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_018.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_018.wav, segment:6
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_016.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_016.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_016.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_016.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_016.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_015.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_015.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_015.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_015.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_015.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_015.wav, segment:6
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_017.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_017.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_017.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_017.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_017.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_017.wav, segment:6
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_019.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_019.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_019.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_019.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_019.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_019.wav, segment:6
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_012.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_012.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_012.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_012.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_012.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_012.wav, segment:6
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_013.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_013.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_013.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_013.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_013.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_013.wav, segment:6
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_014.wav, segment:1
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_014.wav, segment:2
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_014.wav, segment:3
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_014.wav, segment:4
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_014.wav, segment:5
# /content/drive/MyDrive/Final_Data/Double Stop/Double_stop_014.wav, segment:6
# ...
# /content/drive/MyDrive/Final_Data/Detache/Detache_070.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_070.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_070.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_070.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_070.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_070.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_060.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_060.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_060.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_060.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_060.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_060.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_066.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_066.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_066.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_066.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_066.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_066.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_059.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_059.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_059.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_059.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_059.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_059.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_063.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_063.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_063.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_063.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_063.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_063.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_062.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_062.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_062.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_062.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_062.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_062.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_061.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_061.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_061.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_061.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_061.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_061.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_064.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_064.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_064.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_064.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_064.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_064.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_065.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_065.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_065.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_065.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_065.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_065.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_074.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_074.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_074.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_074.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_074.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_074.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_080.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_080.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_080.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_080.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_080.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_080.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_078.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_078.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_078.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_078.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_078.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_078.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_079.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_079.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_079.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_079.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_079.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_079.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_072.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_072.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_072.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_072.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_072.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_072.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_075.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_075.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_075.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_075.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_075.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_075.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_071.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_071.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_071.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_071.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_071.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_071.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_073.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_073.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_073.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_073.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_073.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_073.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_076.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_076.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_076.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_076.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_076.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_076.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_077.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_077.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_077.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_077.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_077.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_077.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_082.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_082.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_082.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_082.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_082.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_082.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_081.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_081.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_081.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_081.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_081.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_086.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_086.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_086.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_086.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_086.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_086.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_083.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_083.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_083.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_083.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_083.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_084.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_084.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_084.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_084.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_084.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_085.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_085.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_085.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_085.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_085.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_085.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_088.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_088.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_088.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_088.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_088.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_088.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_091.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_091.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_091.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_091.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_091.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_091.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_092.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_092.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_092.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_092.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_092.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_092.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_090.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_090.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_090.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_090.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_090.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_090.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_087.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_087.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_087.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_087.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_087.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_087.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_089.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_089.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_089.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_089.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_089.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_089.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_093.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_093.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_093.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_093.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_093.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_093.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_094.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_094.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_094.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_094.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_094.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_094.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_095.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_095.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_095.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_095.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_095.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_095.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_100.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_100.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_100.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_100.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_100.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_100.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_097.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_097.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_097.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_097.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_097.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_097.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_096.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_096.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_096.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_096.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_096.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_096.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_099.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_099.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_099.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_099.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_099.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_099.wav, segment:6
# /content/drive/MyDrive/Final_Data/Detache/Detache_098.wav, segment:1
# /content/drive/MyDrive/Final_Data/Detache/Detache_098.wav, segment:2
# /content/drive/MyDrive/Final_Data/Detache/Detache_098.wav, segment:3
# /content/drive/MyDrive/Final_Data/Detache/Detache_098.wav, segment:4
# /content/drive/MyDrive/Final_Data/Detache/Detache_098.wav, segment:5
# /content/drive/MyDrive/Final_Data/Detache/Detache_098.wav, segment:6

# %%
DATA_PATH = "./data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    z = np.array(data['mapping'])
    return X, y, z


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    :return z : Mappings for data
    """

    # load data
    X, y, z = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=400)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=100)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test, z


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(128, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())
    
  
    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(128, activation='relu'))
    model.add(keras.layers.Dropout(0.5))
    


    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X
                              )

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)
    
    # get mappings for target and predicted label
    target = z[y]
    predicted = z[predicted_index]

    print("Target: {}, Predicted label: {}".format(target, predicted))

# %%
import time
start = time.time()
# get train, validation, test splits
X_train, X_validation, X_test, y_train, y_validation, y_test, z = prepare_datasets(0.25, 0.2)

# create network
input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# train model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=50)

# plot accuracy/error for training and validation
plot_history(history)



# evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 20, 24, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 12, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10, 12, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 10, 64)         18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 5, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 5, 64)          256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 4, 128)         32896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 119,562
# Trainable params: 119,114
# Non-trainable params: 448
# _________________________________________________________________
# Epoch 1/50
# 78/78 [==============================] - 4s 34ms/step - loss: 2.7941 - accuracy: 0.1985 - val_loss: 1.7099 - val_accuracy: 0.4100
# Epoch 2/50
# 78/78 [==============================] - 2s 30ms/step - loss: 1.4247 - accuracy: 0.4872 - val_loss: 1.2933 - val_accuracy: 0.6600
# Epoch 3/50
# 78/78 [==============================] - 2s 31ms/step - loss: 1.0501 - accuracy: 0.6310 - val_loss: 0.9910 - val_accuracy: 0.8200
# Epoch 4/50
# 78/78 [==============================] - 2s 31ms/step - loss: 0.9086 - accuracy: 0.6837 - val_loss: 0.7851 - val_accuracy: 0.8400
# Epoch 5/50
# 78/78 [==============================] - 2s 31ms/step - loss: 0.7782 - accuracy: 0.7201 - val_loss: 0.6725 - val_accuracy: 0.8000
# Epoch 6/50
# 78/78 [==============================] - 2s 31ms/step - loss: 0.7413 - accuracy: 0.7447 - val_loss: 0.5807 - val_accuracy: 0.8600
# Epoch 7/50
# 78/78 [==============================] - 2s 31ms/step - loss: 0.6246 - accuracy: 0.7763 - val_loss: 0.5164 - val_accuracy: 0.8700
# Epoch 8/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.5699 - accuracy: 0.8010 - val_loss: 0.5057 - val_accuracy: 0.8500
# Epoch 9/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.5277 - accuracy: 0.8180 - val_loss: 0.4517 - val_accuracy: 0.8600
# Epoch 10/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.4852 - accuracy: 0.8298 - val_loss: 0.4221 - val_accuracy: 0.9000
# Epoch 11/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.4129 - accuracy: 0.8589 - val_loss: 0.4890 - val_accuracy: 0.8800
# Epoch 12/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.3888 - accuracy: 0.8654 - val_loss: 0.4093 - val_accuracy: 0.9000
# Epoch 13/50
# 78/78 [==============================] - 2s 31ms/step - loss: 0.3712 - accuracy: 0.8731 - val_loss: 0.4099 - val_accuracy: 0.9000
# Epoch 14/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.3310 - accuracy: 0.8864 - val_loss: 0.3753 - val_accuracy: 0.9000
# 78/78 [==============================] - 2s 30ms/step - loss: 0.1123 - accuracy: 0.9670 - val_loss: 0.2947 - val_accuracy: 0.9100
# Epoch 35/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0975 - accuracy: 0.9692 - val_loss: 0.3240 - val_accuracy: 0.9200
# Epoch 36/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.1069 - accuracy: 0.9686 - val_loss: 0.2938 - val_accuracy: 0.9300
# Epoch 37/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0964 - accuracy: 0.9677 - val_loss: 0.2696 - val_accuracy: 0.9200
# Epoch 38/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0937 - accuracy: 0.9740 - val_loss: 0.2864 - val_accuracy: 0.9200
# Epoch 39/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0944 - accuracy: 0.9689 - val_loss: 0.3130 - val_accuracy: 0.9200
# Epoch 40/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0999 - accuracy: 0.9679 - val_loss: 0.2983 - val_accuracy: 0.9000
# Epoch 41/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0800 - accuracy: 0.9751 - val_loss: 0.3810 - val_accuracy: 0.8900
# Epoch 42/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0790 - accuracy: 0.9774 - val_loss: 0.3013 - val_accuracy: 0.9200
# Epoch 43/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0628 - accuracy: 0.9850 - val_loss: 0.3181 - val_accuracy: 0.9000
# Epoch 44/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0776 - accuracy: 0.9756 - val_loss: 0.2518 - val_accuracy: 0.9200
# Epoch 45/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0653 - accuracy: 0.9841 - val_loss: 0.2782 - val_accuracy: 0.9300
# Epoch 46/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0715 - accuracy: 0.9818 - val_loss: 0.2607 - val_accuracy: 0.9200
# Epoch 47/50
# 78/78 [==============================] - 2s 29ms/step - loss: 0.0533 - accuracy: 0.9858 - val_loss: 0.2957 - val_accuracy: 0.9300
# Epoch 48/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0592 - accuracy: 0.9880 - val_loss: 0.2823 - val_accuracy: 0.9400
# Epoch 49/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0677 - accuracy: 0.9800 - val_loss: 0.2707 - val_accuracy: 0.9100
# Epoch 50/50
# 78/78 [==============================] - 2s 30ms/step - loss: 0.0551 - accuracy: 0.9844 - val_loss: 0.3119 - val_accuracy: 0.9300
# 13/13 - 0s - loss: 0.1653 - accuracy: 0.9375
#
# Test accuracy: 0.9375
# Runtime of the program is 121.73360443115234

# %%
start = time.time()
X_to_predict = X_test[3]
y_to_predict = y_test[3]

# predict sample
predict(model, X_to_predict, y_to_predict)
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# Target: Legato, Predicted label: ['Legato']
# Runtime of the program is 0.14022040367126465
